# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.plot([0, 20, 30, 40, 90], [100, 175, 255, 300, 400])
plt.grid()
plt.show()

# %%
plt.style.use('ggplot')
plt.plot([10, 20, 30], [100, 175, 225], marker='o')
plt.grid()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('tableau-colorblind10')
x = [10, 20, 30]
y = [100, 175, 225]
plt.plot(x, y, marker='^')

plt.title('Speed (km/h) v/s Calories burnt on Sunday')
plt.xlabel('Speed (km/h)')
plt.ylabel('Calories Burnt')
plt.show()

# %%
plt.style.use('ggplot')

plt.plot([10, 20, 30], [100, 175, 225], marker='o', label='Sunday')
plt.plot([10, 20, 30], [120, 200, 250], marker='*', label='Monday')
plt.plot([10, 20, 30], [90, 160, 200], marker='^', label='Tuesday')

plt.title('Speed (km/h) v/s Calories burnt', fontsize=10)
plt.xlabel('Speed (km/h)')
plt.ylabel('Calories burnt')

plt.xticks(np.arange(0, 40, 5))
plt.yticks(np.arange(75, 250, 25))

plt.legend(loc='upper left')
plt.show()

# %%
plt.style.use('ggplot')

plt.plot([10, 20, 30], [100, 175, 225], 'g', marker='o', label='Sunday')
plt.plot([10, 20, 30], [120, 200, 250], 'y', marker='*', label='Monday')
plt.plot([10, 20, 30], [90, 160, 200], 'r', marker='^', label='Tuesday')

plt.title('Speed (km/h) v/s Calories burnt', fontsize=10)
plt.xlabel('Speed (km/h)')
plt.ylabel('Calories burnt')

plt.xticks(np.arange(0, 40, 5))
plt.yticks(np.arange(75, 250, 25))

plt.legend(loc='upper left')
plt.show()

# %%
plt.style.use('ggplot')

plt.plot([10, 20, 30], [100, 175, 225], 'g',
         linestyle='--', marker='o', label='Sunday')
plt.plot([10, 20, 30], [120, 200, 250], 'y',
         linestyle='-', marker='*', label='Monday')
plt.plot([10, 20, 30], [90, 160, 200], 'r',
         linestyle=':', marker='^', label='Tuesday')

plt.title('Speed (km/h) v/s Calories burnt', fontsize=10)
plt.xlabel('Speed (km/h)')
plt.ylabel('Calories burnt')

plt.xticks(np.arange(0, 40, 5))
plt.yticks(np.arange(75, 250, 25))

plt.legend(loc='upper left')
plt.show()

# %%
rainfall = pd.read_csv(
    'D:\\workflow\\dt_learn_data_science\\edureka\\works_notebooks\\Class_Work_1_7\\Module 7\\rainfall_in_kerala.csv', index_col=0)

# %%
rainfall
# Out:
#        JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG    SEP    OCT  \
# 1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5  197.7  266.9
# 1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8  491.6  358.4
# 1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2  341.8  354.1
# 1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8  222.7  328.1
# 1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6  217.2  383.5
# ...    ...   ...   ...    ...    ...     ...     ...    ...    ...    ...
# 2011  20.5  45.7  24.1  165.2  124.2   788.5   536.8  492.7  391.2  227.2
# 2012   7.4  11.0  21.0  171.1   95.3   430.3   362.6  501.6  241.1  187.5
# 2013   3.9  40.1  49.9   49.3  119.3  1042.7   830.2  369.7  318.6  259.9
# 2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8  733.9  298.8  355.5
# 2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0  252.2  292.9  308.1
#
#         NOV    DEC  ANNUAL
# 1901  350.8   48.4  3248.6
# ...

# %%
print(rainfall["ANNUAL"].loc["1995":"2000"])
plt.plot(rainfall.ANNUAL.loc["1995":"2000"], 'g', marker='o')
plt.title("90s rainfall statistics")
plt.xlabel("Years of Kerala")
plt.ylabel("Rainfall")
# Out:
# 1995    2858.8
# 1996    2610.0
# 1997    3252.4
# 1998    3151.5
# 1999    2914.6
# 2000    2412.6
# Name: ANNUAL, dtype: float64
# Text(0, 0.5, 'Rainfall')

# %%
plt.style.use('ggplot')
plt.plot(rainfall.loc[1996, 'JAN':'DEC'], 'g',
         linestyle='-', marker='o', label='year 1996')
plt.plot(rainfall.loc[2000, 'JAN':'DEC'], 'hotpink',
         linestyle='--', marker='*', label='year 2000')
plt.plot(rainfall.loc[2015, 'JAN':'DEC'], 'r',
         linestyle='-', marker='^', label='year 2015')
plt.xlabel('Months')
plt.ylabel('Rainfall Data')
plt.title('Rainfalls')
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot([4, 3, 5, 6, 7, 8, 9, 2, 6, 5], 'ro')

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 8, 9])
plt.style.use('ggplot')
plt.bar(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 8, 9])
plt.style.use('ggplot')
plt.barh(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 8, 9])
plt.style.use('ggplot')
plt.bar(x, y, color="green")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 8, 9])
plt.style.use('ggplot')
plt.bar(x, y, color="green", width=0.5)
plt.show()

# %%
data_dict = {'CSE': 33, 'ECE': 98, 'GHT': 58, 'NJU': 33}
courses = list(data_dict.keys())
values = list(data_dict.values())

fig = plt.figure(figsize=(5, 5))

plt.bar(courses, values, color="blue", width=0.4)
plt.xlabel("Courses Offered")
plt.ylabel("Students")
plt.title("Student enrolled in different courses")
plt.show()

# %%
plt.style.use('ggplot')

plt.bar([0.5, 1.25, 2.25, 3.25, 4.25], [
        10, 50, 30, 80, 20], label="BMW", width=.3)
plt.bar([0.75, 1.75, 2.75, 3.75, 4.75], [
        80, 20, 20, 50, 60], label="AUD", width=.3)
plt.bar([0.50, 1.50, 2.50, 3.50, 4.50], [
        50, 30, 70, 40, 35], label="TLS", width=.3)
plt.legend()
plt.xlabel("Days")
plt.ylabel("Distance(kms")
plt.title("Information")
plt.show()

# %%
x = ['A', 'B', 'C', 'D']
y1 = [10, 20, 10, 30]
y2 = [20, 25, 15, 25]

plt.style.use('ggplot')
plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
plt.show()

# %%
plt.style.use('ggplot')

plt.bar([0.5, 1.25, 2.25, 3.25, 4.25], [50, 50, 30, 80, 20], label="BMW", width=.5)
plt.bar([0.5, 1.25, 2.25, 3.25, 4.25], [10, 20, 20, 50, 60], label="AUD", width=.5)
plt.legend()
plt.xlabel("Days")
plt.ylabel("Distance(kms")
plt.title("Information")
plt.show()

# %%
y = np.array([35,25,25,15])
plt.pie(y)
plt.show()

# %%
y = np.array([35,25,25,15])
labels = ["Apples", "Oranges", "Pears", "Grapes"]
fig = plt.figure(figsize=(7,7))
plt.pie(y, labels=labels)
plt.show()

# %%
y = np.array([35,25,25,15])
labels = ["Apples", "Oranges", "Pears", "Grapes"]
fig = plt.figure(figsize=(7,7))
plt.pie(y, labels=labels, startangle=90)
plt.show()

# %%
y = np.array([35,25,25,15])
labels  = ["Apples", "Oranges", "Pears", "Grapes"]
colors  = ["red", "orange", "yellow", "green"]
explode = [0.1, 0, 0, 0]

fig = plt.figure(figsize=(7,7))

plt.pie(y, labels=labels,colors=colors, explode=explode,shadow=True, startangle=90)
plt.show()

# %%
y = np.array([35,25,25,15])
labels  = ["Apples", "Oranges", "Pears", "Grapes"]
colors  = ["red", "orange", "yellow", "green"]
explode = [0.1, 0, 0, 0]

fig = plt.figure(figsize=(10,10))

plt.pie(y, labels=labels,colors=colors, explode=explode,shadow=True, startangle=90, autopct="%0.1f")
plt.legend(title="Fruits", loc="upper left")
plt.show()

# %%
x = np.random.randint(0, 15, 20)
y = np.random.randint(80,115,20)
plt.style.use('fivethirtyeight')
plt.scatter(x, y)
plt.show()

# %%
x = np.random.randint(0, 15, 20)
y = np.random.randint(80,115,20)
plt.style.use('fivethirtyeight')
plt.scatter(x, y, color='hotpink')

x = np.random.randint(0, 15, 20)
y = np.random.randint(80,115,20)
plt.style.use('fivethirtyeight')
plt.scatter(x, y, color='green')

plt.title('Scatter Plot 2 Datasets')

plt.show()

# %%
x = np.random.randn(40)
plt.hist(x, bins=5, edgecolor='yellow', color='green')
plt.xlabel('data')
plt.ylabel('frequency')
plt.title('Histogram')
plt.show()

# %%
x = np.random.randint(20,40,12)
plt.boxplot(x, vert=False, showcaps=True, showfliers=False)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()
