# %%
import pandas as pd

# %%
df = pd.read_csv('/home/pydev/workflow/dt_learn_data_science/python/statistics/simplilearn/houseprices.csv', parse_dates=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   OrganisationLabel             96 non-null     object
#  1   OrganisationURI               96 non-null     object
#  2   PublishedDate                 96 non-null     object
#  3   LatestData                    8 non-null      object
#  4   DurationFrom                  96 non-null     object
#  5   DurationTo                    96 non-null     object
#  6   ReportingPeriodType           96 non-null     object
#  7   Month                         96 non-null     object
#  8   GeoEntityName                 96 non-null     object
#  9   GeoCode                       96 non-null     object
#  10  GeoName                       96 non-null     object
#  11  GeoURI                        96 non-null     object
# ...

# %%
df.head()
# Out:
#   OrganisationLabel                                    OrganisationURI  \
# 0      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 1      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 2      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 3      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 4      Lincolnshire  http://opendatacommunities.org/id/county-counc...
#
#          PublishedDate LatestData         DurationFrom           DurationTo  \
# 0  2023-01-19T00:00:00       True  2022-11-01T00:00:00  2022-11-30T23:59:59
# 1  2023-01-19T00:00:00       True  2022-11-01T00:00:00  2022-11-30T23:59:59
# 2  2023-01-19T00:00:00       True  2022-11-01T00:00:00  2022-11-30T23:59:59
# 3  2023-01-19T00:00:00       True  2022-11-01T00:00:00  2022-11-30T23:59:59
# 4  2023-01-19T00:00:00       True  2022-11-01T00:00:00  2022-11-30T23:59:59
#
#   ReportingPeriodType    Month     GeoEntityName    GeoCode         GeoName  \
# ...

# %%
df.set_index(['OrganisationLabel','Month'], inplace=True)

# %%
df.index
# Out:
# MultiIndex([('Lincolnshire', '2022-11'),
#             ('Lincolnshire', '2022-11'),
#             ('Lincolnshire', '2022-11'),
#             ('Lincolnshire', '2022-11'),
#             ('Lincolnshire', '2022-11'),
#             ('Lincolnshire', '2022-11'),
#             ('Lincolnshire', '2022-11'),
#             ('Lincolnshire', '2022-11'),
#             ('Lincolnshire', '2022-10'),
#             ('Lincolnshire', '2022-10'),
#             ('Lincolnshire', '2022-10'),
#             ('Lincolnshire', '2022-10'),
#             ('Lincolnshire', '2022-10'),
#             ('Lincolnshire', '2022-10'),
#             ('Lincolnshire', '2022-10'),
#             ('Lincolnshire', '2022-10'),
#             ('Lincolnshire', '2022-09'),
#             ('Lincolnshire', '2022-09'),
#             ('Lincolnshire', '2022-09'),
#             ('Lincolnshire', '2022-09'),
#             ('Lincolnshire', '2022-09'),
#             ('Lincolnshire', '2022-09'),
#             ('Lincolnshire', '2022-09'),
# ...

# %%
df.loc['Lincolnshire']
# Out:
#                                            OrganisationURI  \
# Month
# 2022-11  http://opendatacommunities.org/id/county-counc...
# 2022-11  http://opendatacommunities.org/id/county-counc...
# 2022-11  http://opendatacommunities.org/id/county-counc...
# 2022-11  http://opendatacommunities.org/id/county-counc...
# 2022-11  http://opendatacommunities.org/id/county-counc...
# ...                                                    ...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
#
#                PublishedDate LatestData         DurationFrom  \
# Month
# 2022-11  2023-01-19T00:00:00       True  2022-11-01T00:00:00
# 2022-11  2023-01-19T00:00:00       True  2022-11-01T00:00:00
# ...

# %%
df.loc['Lincolnshire'].loc['2021-12']
# Out:
#                                            OrganisationURI  \
# Month
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
# 2021-12  http://opendatacommunities.org/id/county-counc...
#
#                PublishedDate LatestData         DurationFrom  \
# Month
# 2021-12  2023-01-19T00:00:00        NaN  2021-12-01T00:00:00
# 2021-12  2023-01-19T00:00:00        NaN  2021-12-01T00:00:00
# 2021-12  2023-01-19T00:00:00        NaN  2021-12-01T00:00:00
# 2021-12  2023-01-19T00:00:00        NaN  2021-12-01T00:00:00
# 2021-12  2023-01-19T00:00:00        NaN  2021-12-01T00:00:00
# ...
